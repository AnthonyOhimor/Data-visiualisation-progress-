# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as pyt
# %matplotlib inline 

print("Complet setup ")
# Out:
# Complet setup

# %%
df=pd.read_csv('https://stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv')

# %%
pd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 pd.head()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'head'

# %%
pd
# Out:
# <module 'pandas' from '/Users/donquixxy/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py'>

# %%
df = pd.read_csv('Desktop/ethnic-group-total-responses-2018-census-csv.csv')

# %%
df.head()
# Out:
#     Code          Ethnic_group  Census_night_population_count  \
# 0  10000          European nfd                          38187
# 1  11111  New Zealand European                        3025587
# 2  12100           British nfd                          16545
# 3  12111            Celtic nfd                            570
# 4  12112      Channel Islander                             96
#
#    Census_usually_resident_population_count
# 0                                     34632
# 1                                   3013440
# 2                                     11607
# 3                                       558
# 4                                        96

# %%
pyt.figure(figsize=(16,10))
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
yield_apples = [0.895, 0.91,0.919,0.926,0.929,0.931]
pyt.plot (yield_apples)

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]

# %%
pyt.plot (years, yield_apples)

# %%
pyt.plot (years, yield_apples)
pyt.xlabel('Year')
pyt.ylabel('Yield (tons per hectare)') ;

# %%
years = range (2000, 2012)
apples = [0.895, 0.91, 0.919,0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904,0.901, 0.898, 0.9, 0.896];

# %%
pyt.plot(years, apples)
pyt.plot(years, oranges)
pyt.xlabel('Year')
pyt.ylabel("Vield (tons per hectare)" );

# %%
pyt. figure (figsize=(12, 6))
pyt.plot (years, oranges, marker='o')
pyt. title("Yield of Oranges (tons per hectare)" )
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hectare)')

# %%
sns.set_style("whitegrid")

# %%
sns.set_style("whitegrid")
pyt.figure (figsize=(12, 6))
pyt.plot (years, oranges, marker='o')
pyt. title("Yield of Oranges (tons per hectare)" )
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hectare)')

# %%
pyt.figure(figsize=(16,8))
pyt.bar(years, apples)
pyt.bar(years, oranges, bottom= apples)
pyt.xlabel('Year')
pyt.ylabel("Vield (tons per hectare)" );

# %%
sns_df = sns.load_dataset('https://stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 sns_df = sns.load_dataset('https://stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:595, in load_dataset(name, cache, data_home, **kws)
#     593 if not os.path.exists(cache_path):
#     594     if name not in get_dataset_names():
# --> 595         raise ValueError(f"'{name}' is not one of the example datasets.")
#     596     urlretrieve(url, cache_path)
#     597 full_path = cache_path
#
# ...

# %%
sns_dataset = sns.load_dataset('tips')
sns_dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=sns_dataset)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
flowers_df = sns.load_dataset("iris")
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
flowers_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
pyt.hist (flowers_df.sepal_width, bins=np.arange(2,6,0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 pyt.hist (flowers_df.sepal_width, bins=np.arange(2,6,0.5))
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
pyt.hist (flowers_df.sepal_width, bins=np.arange(2,6,0.5))
# Out:
# (array([11., 46., 68., 21.,  4.,  0.,  0.]),
#  array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5]),
#  <BarContainer object of 7 artists>)

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
setosa_df = flowers_df[flowers_df.species =='setosa']
versicolor_df = flowers_df[flowers_df.species=='versicolor']
virginica_df = flowers_df[flowers_df.species=='virginica']

# %%
pyt.title('Distributionof Sepal width')
pyt.hist ([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],
bins=np.arange(2, 5, 0.25),stacked=True);
          
pyt.legend (['Setosa','Versicolor','Virginica']);

# %%
flight_dataset=sns.load_dataset('flights').pivot("month", "year","passengers")

# %%
df=flight_dataset

# %%
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pyt.title("Heatmap distribution ")
sns.heatmap(flight_dataset)
# Out:
# <AxesSubplot:title={'center':'Heatmap distribution '}, xlabel='year', ylabel='month'>
